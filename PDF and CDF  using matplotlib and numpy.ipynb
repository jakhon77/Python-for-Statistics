# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# ### Let's build PDF and CDF of the Gausssian Function

# %%
X = np.arange(-2,2,0.01)
Y = exp(-X**2)

# %%
# Out:
# 0.4410403901256501

# %%
Y.sum()
# Out:
# 1.154696929934432

# %% [markdown]
# #### Normalize the data to make sure the area under the PDF is equal to 1

# %%
Y = Y/(Y/100).sum()
Y.sum()
# Out:
# 100.0

# %%
CY = np.cumsum(Y/100)

# %%
plt.figure(figsize = (15, 8))
plt.plot(X,Y)
plt.plot(X, CY, 'r--')

# %%
stats.norm.cdf(np.array([-2,-1,0,1,2]))
# Out:
# array([0.02275013, 0.15865525, 0.5       , 0.84134475, 0.97724987])

# %%
within_one_std = stats.norm.cdf(1)-stats.norm.cdf(-1) 
within_one_std
# Out:
# 0.6826894921370859

# %% [markdown]
# #### Can also be defined with a keyword argument moments, which is a string composed of “m”, “v”, “s”, and/or “k”. Only the components appearing in string should be computed and returned in the order “m”, “v”, “s”, or “k” with missing values returned as None.

# %%
stats.norm.stats(loc = 5, scale = 2, moments = 'mv')
# Out:
# (array(5.), array(4.))

# %%
rv = stats.t.rvs(df = 30, size = 1000)
stats.describe(rv)
# Out:
# DescribeResult(nobs=1000, minmax=(-3.3568670845218236, 3.0897578890256114), mean=0.03289475644397726, variance=0.953973678676406, skewness=-0.006842408411386688, kurtosis=-0.08558831689829471)
