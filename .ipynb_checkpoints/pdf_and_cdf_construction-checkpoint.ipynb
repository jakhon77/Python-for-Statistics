# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The main python module that is run should import random and call random.seed(n) - this is shared between all other imports of random as long as somewhere else doesn't reset the seed.

# %% [markdown]
# ### The function numpy.random.default_rng will instantiate a Generator with numpy’s default BitGenerator.

# %%
rng = np.random.default_rng(77)
rng
# Out:
# Generator(PCG64) at 0x2134C6D0E58

# %% [markdown]
# ### generator instance used by the generator

# %%
rng.bit_generator

# %%
rng.integers(1000)
# Out:
# 59

# %%
mu, sigma = 7, 1.7

# %%
data = rng.normal(mu, sigma, 10000)

# %%
pd.Series(data).describe().round(2)
# Out:
# count    10000.00
# mean         7.00
# std          1.70
# min          0.77
# 25%          5.86
# 50%          7.02
# 75%          8.15
# max         14.13
# dtype: float64

# %%
sns.distplot(data)

# %%
sample_1 = rng.choice(data, size = 100)
sample_2 = rng.choice(data, size = 100)
sample_3 = rng.choice(data, size = 100)

# %%
sns.distplot(sample_1, hist = False)
sns.distplot(sample_2, hist = False)
sns.distplot(sample_3, hist = False)

# %%
fig, ax = plt.subplots(figsize = (15,8))
sns.distplot(data)
plt.axvline(np.mean(data)-np.std(data), ymax = 0.52, color = 'red' )
plt.axvline(np.mean(data)+np.std(data), ymax = 0.52, color = 'red' )

plt.axvline(np.mean(data)-(np.std(data)*2), ymax = 0.12, color = 'green' )
plt.axvline(np.mean(data)+(np.std(data)*2), ymax = 0.12, color = 'green' )

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(data)
plt.plot(ecdf.x, ecdf.y)

# %%
len(ecdf.x)
# Out:
# 10001
